# %% [markdown]
# # matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot([1,2,3,4])
plt.ylabel('size')
plt.xlabel('age')
# Out:
# Text(0.5, 0, 'age')

# %%
plt.plot([1,3,4,9],[-3,-1,6,7])

# %%
plt.plot([1,3,4,9],[-3,-1,6,7], 'ro')   #b+

# %%
t=np.arange(0,5,0.2)
plt.plot(t, t, 'r-*',t, t**2 , 'b*', t,t**3, 'g^')
# plt.plot(t,t*2)

# %%
data={
    'a':np.arange(500),
    'b':np.random.randint(0,50,50),   # 50 تا بین 0 تا  50
    'c':np.random.randn(500)
}

# %%
plt.scatter(data['a'], data['c'])

# %%
msk=np.random.rand(len(df)) <0.8
train=cdf[msk]
test=cdf[~msk]
print(msk)
pri
print(train)
print(test)
